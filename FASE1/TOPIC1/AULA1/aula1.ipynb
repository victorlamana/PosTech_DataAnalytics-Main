# %% [markdown]
# Analisando dados de produção hospitalar
# -Victor Lamana

# %%
import pandas as pd

# %%
dados = pd.read_csv("E:\Onedrive\OneDrive - Louis Dreyfus Company\Personal\STUDY\POSTECH\AULA1\pos-datascience-analise-e-exploracao-de-dados-Dados\A150850189_28_143_208.csv",encoding='ISO-8859-1', skiprows=3,sep=';',skipfooter=12, thousands='.',decimal=',')
# Out:
# c:\Miniconda\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2021/Jan     2021/Fev     2021/Mar  \
# 0        -        -        -  ...  10045624.39  10677245.18  18147121.02
# 1        -        -        -  ...   4175526.06   5282655.42   5699597.78
# 2        -        -        -  ...  27406458.57  22341042.63  27923786.94
# 3        -        -        -  ...   3557821.99   4172285.82   5427226.70
# 4        -        -        -  ...  39042349.46  37113440.70  49625416.13
#
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...      2021/Jan      2021/Fev  \
# 22        -        -        -        -  ...  1.159919e+08  1.267303e+08
# 23        -        -        -        -  ...  2.472700e+07  2.560076e+07
# 24        -        -        -        -  ...  1.888971e+07  2.154459e+07
# 25        -        -        -        -  ...  4.263870e+07  4.571547e+07
# 26        -        -        -        -  ...  2.448472e+07  2.415606e+07
#
#         2021/Mar      2021/Abr      2021/Mai      2021/Jun      2021/Jul  \
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %%
pd.options.display.float_format="{:.2f}".format

# %%
dados["2008/Ago"].mean()
# Out:
# 26645398.35703704

# %%
dados.plot(x="Unidade da Federação", y = "2008/Jan")
dados.plot(x="Unidade da Federação", y = "2008/Ago")
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
dados.plot(x="Unidade da Federação", y = "2008/Ago", kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
dados.plot(x="Unidade da Federação", y = "2008/Ago", kind='bar', figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
import matplotlib.ticker as ticker
axis = dados.plot(x="Unidade da Federação", y = "2008/Ago", kind='bar', figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %%
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

axis = dados.plot(x="Unidade da Federação", y = "2008/Ago", kind='bar', figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor por unidade de federação")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai', '2021/Jun',
#        '2021/Jul', '2021/Ago', '2021/Set', 'Total'],
#       dtype='object', length=293)

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis[:5]
# Out:
# C:\Users\lamanv\AppData\Local\Temp\4/ipykernel_12084/4199419275.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   colunas_usaveis = dados.mean().index.tolist()
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  9469279.43
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3820865.83
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 21911210.94
# 3   808448.39   771687.83   876091.18   896952.53  ...  3193708.89
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 37925512.28
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# ...

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
dados_usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2021/Mai               17659855.79   4326882.24   23973537.71   3681417.80
# 2021/Jun               14435903.47   3458187.11   22175398.40   3475205.55
# 2021/Jul               11834435.10   2302711.01   21614943.55   3320807.96
# 2021/Ago                7371334.84   1196754.85   13806958.66   2907871.07
# Total                1088059702.25 475290315.34 2061943006.93 352546288.71
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2021/Mai               50907226.77   5672086.52   10161783.68   55324683.42
# 2021/Jun               43876590.47   5469150.38    6349488.16   51958573.27
# 2021/Jul               33718084.12   4136950.62    4610170.61   37775425.78
# 2021/Ago               20837865.89   1875241.91    2304080.49   25779674.83
# Total                4968811817.17 337181964.14 1110344733.46 4161325769.23
#
# ...

# %%
dados_usaveis = dados_usaveis.drop("Total", axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
dados_usaveis.T.max()
# Out:
# Unidade da Federação
# 11 Rondônia                18147121.02
# 12 Acre                     5699597.78
# 13 Amazonas                27923786.94
# 14 Roraima                  5427226.70
# 15 Pará                    52558327.29
# 16 Amapá                    5672086.52
# 17 Tocantins               10161783.68
# 21 Maranhão                55324683.42
# 22 Piauí                   32550777.47
# 23 Ceará                  102825954.51
# 24 Rio Grande do Norte     41819897.10
# 25 Paraíba                 39602463.80
# 26 Pernambuco             132095684.99
# 27 Alagoas                 30875169.00
# 28 Sergipe                 19720608.49
# 29 Bahia                  134229720.19
# 31 Minas Gerais           275151838.35
# 32 Espírito Santo          58031849.50
# 33 Rio de Janeiro         252175779.88
# 35 São Paulo             1049827695.26
# 41 Paraná                 191861617.22
# 42 Santa Catarina         101661537.37
# 43 Rio Grande do Sul      169687680.33
# ...

# %%
import matplotlib.pyplot as plt

dados_usaveis.T.plot(figsize=(12,6))
##plt.legend(loc='lower right')
plt.legend(bbox_to_anchor=(-0.1,-0.1), loc='lower right')
plt.title('lower right')
plt.xlabel('lower right')
plt.ylabel('lower right')
# Out:
# Text(0, 0.5, 'lower right')

# %%
len(dados_usaveis.T.columns)
# Out:
# 27

# %%
dados_usaveis[:7]
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
# 16 Amapá              33672.74 104822.98  118378.28  226661.18   844019.90
# 17 Tocantins           4113.76  76633.06  343702.61 1068685.94  3022200.87
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# ...

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
dados_usaveis.sample(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
import numpy as np

np.random.seed(524387)
dados_usaveis.sample(7)
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 17 Tocantins           4113.76   76633.06   343702.61  1068685.94  3022200.87
# 26 Pernambuco        400640.85 1088340.42  2973553.48  6699828.82 16919031.39
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 22 Piauí             220788.25  353468.67  1078182.68  2406035.32  4929772.93
# 25 Paraíba            97352.78  368130.43  1002088.64  2149873.40  5448177.36
# 29 Bahia             135146.36  448349.75  1382038.11  3348779.62 11948984.56
# 42 Santa Catarina    693955.05 1092964.12  3562300.82  7578502.38 14772555.10
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins           5136474.61  5051932.07  5200151.87  5343714.73
# 26 Pernambuco         51279301.86 26222079.10 30716361.81 30589332.79
# 31 Minas Gerais      206493861.30 70301089.50 79119005.51 79046322.41
# ...

# %%
dados_usaveis.sample(7).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
##Ordenar

ordenados_por_total = dados_usaveis.sort_values(by="Total", ascending=False)
ordenados_por_total
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo           1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais         971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná               554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul   1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro       469469.34  921646.57  2994664.57  7250528.08
# 29 Bahia                135146.36  448349.75  1382038.11  3348779.62
# 26 Pernambuco           400640.85 1088340.42  2973553.48  6699828.82
# 42 Santa Catarina       693955.05 1092964.12  3562300.82  7578502.38
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 52 Goiás                179395.82  418053.58  1198730.25  2712117.54
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# ...

# %%
##Coluna regiao com cada estado
list(dados_usaveis.T.columns)
# Out:
# ['11 Rondônia',
#  '12 Acre',
#  '13 Amazonas',
#  '14 Roraima',
#  '15 Pará',
#  '16 Amapá',
#  '17 Tocantins',
#  '21 Maranhão',
#  '22 Piauí',
#  '23 Ceará',
#  '24 Rio Grande do Norte',
#  '25 Paraíba',
#  '26 Pernambuco',
#  '27 Alagoas',
#  '28 Sergipe',
#  '29 Bahia',
#  '31 Minas Gerais',
#  '32 Espírito Santo',
#  '33 Rio de Janeiro',
#  '35 São Paulo',
#  '41 Paraná',
#  '42 Santa Catarina',
#  '43 Rio Grande do Sul',
#  '50 Mato Grosso do Sul',
#  '51 Mato Grosso',
#  '52 Goiás',
#  '53 Distrito Federal']

# %%
#ordenados_por_total.drop("Total",axis=1, inplace=True)
ordenados_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
#ordenados_por_total[6:].head(5).T.plot(figsize=(10,6))
colunas_interessadas = ordenados_por_total.columns[6:]
ordenados_por_total=ordenados_por_total[colunas_interessadas]
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
estados = list(ordenados_por_total.T.columns)
estados
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '29 Bahia',
#  '26 Pernambuco',
#  '42 Santa Catarina',
#  '23 Ceará',
#  '52 Goiás',
#  '15 Pará',
#  '21 Maranhão',
#  '32 Espírito Santo',
#  '24 Rio Grande do Norte',
#  '25 Paraíba',
#  '53 Distrito Federal',
#  '50 Mato Grosso do Sul',
#  '22 Piauí',
#  '27 Alagoas',
#  '51 Mato Grosso',
#  '13 Amazonas',
#  '28 Sergipe',
#  '17 Tocantins',
#  '11 Rondônia',
#  '12 Acre',
#  '14 Roraima',
#  '16 Amapá']

# %%
estadosclean = []
for i in estados:
    estadosclean.append(i[3:])

estadosclean
# Out:
# ['São Paulo',
#  'Minas Gerais',
#  'Paraná',
#  'Rio Grande do Sul',
#  'Rio de Janeiro',
#  'Bahia',
#  'Pernambuco',
#  'Santa Catarina',
#  'Ceará',
#  'Goiás',
#  'Pará',
#  'Maranhão',
#  'Espírito Santo',
#  'Rio Grande do Norte',
#  'Paraíba',
#  'Distrito Federal',
#  'Mato Grosso do Sul',
#  'Piauí',
#  'Alagoas',
#  'Mato Grosso',
#  'Amazonas',
#  'Sergipe',
#  'Tocantins',
#  'Rondônia',
#  'Acre',
#  'Roraima',
#  'Amapá']

# %%
#ordenados_por_total = ordenados_por_total.rename(columns={"":"Unidade da Federação"})
ordenados_por_total.columns.values[-1]
# Out:
# 'Total'

# %%
ordenados_por_total.index = ordenados_por_total.index.map(lambda x: str(x)[3:])
ordenados_por_total.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Paraná', 'Rio Grande do Sul',
#        'Rio de Janeiro', 'Bahia', 'Pernambuco', 'Santa Catarina', 'Ceará',
#        'Goiás', 'Pará', 'Maranhão', 'Espírito Santo', 'Rio Grande do Norte',
#        'Paraíba', 'Distrito Federal', 'Mato Grosso do Sul', 'Piauí', 'Alagoas',
#        'Mato Grosso', 'Amazonas', 'Sergipe', 'Tocantins', 'Rondônia', 'Acre',
#        'Roraima', 'Amapá'],
#       dtype='object', name='Unidade da Federação')

# %%
#ordenados_por_total = dados_usaveis.sort_values(by="Total", ascending=False)
ordenados_por_index = dados_usaveis.sort_index()

# %%
ordenados_por_index
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# 22 Piauí                220788.25  353468.67  1078182.68  2406035.32
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 25 Paraíba               97352.78  368130.43  1002088.64  2149873.40
# ...

# %%
regioes = ['Norte', 'Nordeste', 'Norte', 'Norte', 'Nordeste', 'Nordeste', 'Centro-Oeste', 'Sudeste', 'Centro-Oeste', 'Nordeste', 'Centro-Oeste', 'Centro-Oeste', 'Sudeste', 'Norte', 'Nordeste', 'Sul', 'Nordeste', 'Nordeste', 'Nordeste', 'Sul', 'Sudeste', 'Norte', 'Norte', 'Sul', 'Nordeste', 'Sudeste', 'Norte']

ordenados_por_total["Região"] = regioes
# Out:
# C:\Users\lamanv\AppData\Local\Temp\4/ipykernel_12084/3556453835.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ordenados_por_total["Região"] = regioes

# %%
ordenados_por_index["Região"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Miniconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Miniconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Miniconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Região'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
ordenados_por_total = dados_usaveis.sort_values(by='Total', ascending=False)
ordenados_por_total = ordenados_por_total.drop("Total", axis=1)
ordenados_por_total
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# São Paulo            1665349.90 4434168.64 14577395.84 35032259.98
# Minas Gerais          971394.37 2861781.50 10018011.35 21730281.63
# Paraná                554800.22 1431708.01  4630402.44 11120030.79
# Rio Grande do Sul    1049252.33 3182913.14  8571312.11 16592432.80
# Rio de Janeiro        469469.34  921646.57  2994664.57  7250528.08
# Bahia                 135146.36  448349.75  1382038.11  3348779.62
# Pernambuco            400640.85 1088340.42  2973553.48  6699828.82
# Santa Catarina        693955.05 1092964.12  3562300.82  7578502.38
# Ceará                 357904.65  572356.18  1865065.71  5131814.39
# Goiás                 179395.82  418053.58  1198730.25  2712117.54
# Pará                  181159.29  433414.74  1893197.50  5105406.44
# Maranhão              385330.18 1018352.93  2277717.78  4334468.23
# Espírito Santo         57408.11  284224.80  1152115.25  2296383.23
# ...

# %%
list(ordenados_por_total.columns)
# Out:
# ['2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
# ...

# %%
#ordenados_por_total.columns
ordenados_regiao = ordenados_por_total.set_index("Região")
ordenados_regiao.drop("Total", axis=1,inplace=True)
ordenados_regiao.groupby("Região").sum().plot(figsize=(10,6))
#ordenados_regiao.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\4/ipykernel_12084/2187853092.py in <module>
#       1 #ordenados_por_total.columns
# ----> 2 ordenados_regiao = ordenados_por_total.set_index("Região")
#       3 ordenados_regiao.drop("Total", axis=1,inplace=True)
#       4 ordenados_regiao.groupby("Região").sum().plot(figsize=(10,6))
#       5 #ordenados_regiao.head
#
# NameError: name 'ordenados_por_total' is not defined
